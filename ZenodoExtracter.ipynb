# %%
import requests
import os

def download_zenodo_data(record_id, destination_folder='.', filename=None):

    base_url = f"https://zenodo.org/api/records/{record_id}"

    try:
        response = requests.get(base_url)
        response.raise_for_status()
        data = response.json()

        files = data.get('files', [])
        if not files:
            print(f"No files found : {record_id}")
            return None


        download_file = files[0]

        file_url = download_file['links']['self']
        if not filename:
            filename = download_file['key']

        os.makedirs(destination_folder, exist_ok=True)
        local_filepath = os.path.join(destination_folder, filename)

        print(f"Downloading {filename} from {file_url}...")
        with requests.get(file_url, stream=True) as r:
            r.raise_for_status()
            with open(local_filepath, 'wb') as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        print(f"Download complete: {local_filepath}")
        return local_filepath


    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
path=download_zenodo_data("19509176", destination_folder='.', filename="data.zip")
# Out:
# Downloading data.zip from https://zenodo.org/api/records/19509176/files/data.zip/content...
# Download complete: ./data.zip

# %%
# !unzip "{path}"
# Out:
# Archive:  ./data.zip
#    creating: new_comb_data/
#   inflating: new_comb_data/SRX9770777_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX391995_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX5507864.bw
#   inflating: new_comb_data/SRX9770784_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX215474.bw
#   inflating: new_comb_data/SRX9770790_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX6044213.bw
#   inflating: new_comb_data/SRX130305.bw
#   inflating: new_comb_data/SRX3753856.bw
#   inflating: new_comb_data/SRX9770776_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770792_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770791_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1096548_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX391992_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX3789136.bw
#   inflating: new_comb_data/SRX9770782_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX5012070.bw
#   inflating: new_comb_data/SRX9770779_Rep0.rpgc.bw
#   inflating: new_comb_data/Metadata_toy.csv
#   inflating: new_comb_data/SRX1096551_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770783_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770786_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770773_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770788_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1161361.bw
#   inflating: new_comb_data/SRX5507861.bw
#   inflating: new_comb_data/SRX9770787_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770774_Rep0.rpgc.bw
#   inflating: new_comb_data/DRX092570.bw
#   inflating: new_comb_data/SRX9770785_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX3152333.bw
#   inflating: new_comb_data/SRX9770780_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1098138_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1412761.bw
#   inflating: new_comb_data/SRX391997_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1098137_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX130311.bw
#   inflating: new_comb_data/SRX391990_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770775_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX4478276.bw
#   inflating: new_comb_data/SRX391996_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1098135_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1012884.bw
#   inflating: new_comb_data/SRX215433.bw
#   inflating: new_comb_data/SRX9770781_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX2311142.bw
#   inflating: new_comb_data/SRX4131141.bw
#   inflating: new_comb_data/SRX1098136_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX4705000.bw
#   inflating: new_comb_data/SRX1096549_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX9770793_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX391993_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX4101259.bw
#   inflating: new_comb_data/SRX2240741.bw
#   inflating: new_comb_data/SRX2140205.bw
#   inflating: new_comb_data/SRX391991_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX4478272.bw
#   inflating: new_comb_data/SRX215438.bw
#   inflating: new_comb_data/SRX2467594.bw
#   inflating: new_comb_data/SRX9770778_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1096550_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX391994_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX2140200.bw
#   inflating: new_comb_data/SRX9770789_Rep0.rpgc.bw
#   inflating: new_comb_data/SRX1012869.bw
